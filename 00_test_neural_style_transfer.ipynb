# %% [markdown]
# # Testing our neural style transfer script
#
# In this notebook, we'll simply test our neural style transfer script. The script we're using is from [here](https://github.com/pytorch/examples/tree/master/fast_neural_style) originally and is based off the work from [this](https://arxiv.org/abs/1603.08155) paper.

# %% [markdown]
# ---

# %%
import torch 
from IPython.display import Image

# %% [markdown]
# Make an output and content directory.

# %%
# !rm content_dir output_dir
# !mkdir content_dir && mkdir output_dir

# %% [markdown]
# Download an image to apply style transfer to. The image is downloaded to the `content_dir` that we just created.

# %%
# !wget http://5b0988e595225.cdn.sohucs.com/images/20190709/08fb91e2a04f4def98b601343f9b66e8.jpeg --no-check-certificate -O content_dir/human.jpg
# Out:
# --2019-07-18 03:09:21--  http://5b0988e595225.cdn.sohucs.com/images/20190709/08fb91e2a04f4def98b601343f9b66e8.jpeg
# Resolving 5b0988e595225.cdn.sohucs.com (5b0988e595225.cdn.sohucs.com)... 115.231.20.22, 61.164.210.207
# Connecting to 5b0988e595225.cdn.sohucs.com (5b0988e595225.cdn.sohucs.com)|115.231.20.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25192 (25K) [image/jpeg]
# Saving to: ‘content_dir/human.jpg’
#
# content_dir/human.j 100%[===================>]  24.60K  --.-KB/s    in 0.02s
#
# 2019-07-18 03:09:21 (1.30 MB/s) - ‘content_dir/human.jpg’ saved [25192/25192]

# %%
im = Image(filename="content_dir/human.jpg", width=600)
display(im)

# %% [markdown]
# Apply style transfer using the style transfer script under `/aks/style_transfer.py`.
#
# - `--model-dir` - the model directory where all the model files are saved
# - `--cuda` - 1 to use GPU, 0 to use CPU
# - `--content-dir` - the directory of input images
# - `--output-dir` - the directory to save output images

# %%
# !python scoring_app/style_transfer.py \
    --model-dir models \
    --cuda {1 if torch.cuda.is_available() else 0} \
    --content-dir content_dir \
    --output-dir output_dir

# %% [markdown]
# Check that there is something in the `output_dir`.

# %%
# !ls output_dir

# %% [markdown]
# Display the output image.

# %%
im = Image(filename="output_dir/human.jpg", width=600)
display(im)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-9a3c459363c7> in <module>
# ----> 1 im = Image(filename="output_dir/human.jpg", width=600)
#       2 display(im)
#
# ~/anaconda3/envs/bc_aks/lib/python3.6/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1195         self.unconfined = unconfined
#    1196         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1197                 metadata=metadata)
#    1198
#    1199         if self.width is None and self.metadata.get('width', {}):
#
# ~/anaconda3/envs/bc_aks/lib/python3.6/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     618             self.metadata = {}
#     619
# --> 620         self.reload()
#     621         self._check_data()
#     622
#
# ~/anaconda3/envs/bc_aks/lib/python3.6/site-packages/IPython/core/display.py in reload(self)
#    1226         """Reload the raw data from file or URL."""
#    1227         if self.embed:
# -> 1228             super(Image,self).reload()
#    1229             if self.retina:
#    1230                 self._retina_shape()
#
# ~/anaconda3/envs/bc_aks/lib/python3.6/site-packages/IPython/core/display.py in reload(self)
#     643         """Reload the raw data from file or URL."""
#     644         if self.filename is not None:
# --> 645             with open(self.filename, self._read_flags) as f:
#     646                 self.data = f.read()
#     647         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_dir/human.jpg'

# %% [markdown]
# Continue to the next [notebook](/notebooks/01_setup_azure.ipynb).
